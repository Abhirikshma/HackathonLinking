# %%
import awkward as ak
import numpy as np
import uproot as uproot
import matplotlib
import matplotlib.pyplot as plt
import networkx as nx
# import tensorflow as tf
import glob
from numba import jit
import pickle
import os, errno

# %%
def mkdir_p(mypath):
    '''Function to create a new directory, if it not already exist
        - mypath : directory path
    '''
    from errno import EEXIST
    from os import makedirs,path
    try:
        makedirs(mypath)
    except OSError as exc:
        if exc.errno == EEXIST and path.isdir(mypath):
            pass
        else: raise

# %%
@jit
def computeEdgeAndLabels(trk_data, ass_data, gra_data, nodes, edges, edges_labels):
    '''Compute the truth graph'''
    for i in range(trk_data.NTracksters):
        nodes.append(i)
        qualities = ass_data.tsCLUE3D_recoToSim_CP_score[i]
        best_sts_i = ass_data.tsCLUE3D_recoToSim_CP[i][ak.argmin(qualities)]
        best_sts_i = best_sts_i if qualities[best_sts_i]<0.1 else -1
        for j in gra_data.linked_inners[i]:
            edges.append([j,i])
            qualities = ass_data.tsCLUE3D_recoToSim_CP_score[j]
            best_sts_j = ass_data.tsCLUE3D_recoToSim_CP[j][ak.argmin(qualities)]
            best_sts_j = best_sts_j if qualities[best_sts_j]<0.1 else -1
            if best_sts_i == best_sts_j:
                edges_labels.append(1)
            else:
                edges_labels.append(0)

# %%
input_folder = "/eos/cms/store/group/dpg_hgcal/comm_hgcal/hackathon/samples/close_by_double_pion/production/new_new_ntuples/"
files = glob.glob(f"{input_folder}/*ntuples_*.root")

calos = [ ]
tracksters = [ ]
associations = [ ]
graph = [ ]

X = [ ]
Edges = [ ]
Edges_labels = [ ] 
outputPath  = './dataset_closeByDoublePion/'
mkdir_p(outputPath)

N = 10000000
for i, file in enumerate(files):
    if i >= N: break
    i+=1
    try:
        f = uproot.open(file)
        t =  f["ntuplizer/tracksters"]
        calo = f["ntuplizer/simtrackstersCP"]
        ass = f["ntuplizer/associations"]
        gra = f["ntuplizer/graph"]
        
        trk_data = t.arrays(["NTracksters", "raw_energy","raw_em_energy","barycenter_x","barycenter_y","barycenter_z","eVector0_x", "eVector0_y","eVector0_z"])
        gra_data = gra.arrays(['linked_inners'])
        ass_data = ass.arrays([ "tsCLUE3D_recoToSim_CP", "tsCLUE3D_recoToSim_CP_score"])

        X = [ ]
        Edges = [ ]
        Edges_labels = [ ] 
    
    except:
        print("error ", file)
        continue
    print('\nProcessing file {} '.format(file), end="")
    
    for ev in range(len(gra_data)):
        print(".", end="")


        # Save the input variables

        x_ev = ak.zip({"raw_en": trk_data[ev].raw_energy, 
                       'raw_em_energy': trk_data[ev].raw_em_energy,
                         "barycenter_x": trk_data[ev].barycenter_x,
                         "barycenter_y": trk_data[ev].barycenter_y,
                         "barycenter_z": trk_data[ev].barycenter_z,
                         "eVector0_x": trk_data[ev].eVector0_x,
                         "eVector0_y": trk_data[ev].eVector0_y,
                         "eVector0_z": trk_data[ev].eVector0_z})

        X.append(x_ev)
        nodes = []
        edges = []
        edges_labels = []
        
        computeEdgeAndLabels(trk_data[ev], ass_data[ev], gra_data[ev], nodes, edges, edges_labels)
        ed_np = np.array(edges).T
        Edges.append(ed_np)
        Edges_labels.append(edges_labels)
        
        # Save to disk
        if((ev % 200 == 0 and ev != 0)  or (ev == len(gra_data))):
            print("Saving now the pickle data")

            pickle_dir = outputPath
            with open(pickle_dir+"{}_{}_node_features.pkl".format(str(i_file), str(ev)), "wb") as fp:   #Pickling
                pickle.dump(X, fp)
            with open(pickle_dir+"{}_{}_edges.pkl".format(str(i_file),str(ev)), "wb") as fp:   #Pickling
                pickle.dump(Edges, fp)
            with open(pickle_dir+"{}_{}_edges_labels.pkl".format(str(i_file),str(ev)), "wb") as fp:   #Pickling
                pickle.dump(Edges_labels, fp)
            #Emptying arrays
            ed_np = []
            Edges = []
            Edges_labels = []
# Out:
# error  /eos/cms/store/group/dpg_hgcal/comm_hgcal/hackathon/samples/close_by_double_pion/production/new_new_ntuples/ntuples_3933206_0.root

# %%
# !ls dataset_closeByDoublePion
# Out:
# 0_1000_edges_labels.pkl   1_2200_node_features.pkl  2_3800_edges.pkl
# 0_1000_edges.pkl	  1_2400_edges_labels.pkl   2_3800_node_features.pkl
# 0_1000_node_features.pkl  1_2400_edges.pkl	    2_4000_edges_labels.pkl
# 0_1200_edges_labels.pkl   1_2400_node_features.pkl  2_4000_edges.pkl
# 0_1200_edges.pkl	  1_2600_edges_labels.pkl   2_4000_node_features.pkl
# 0_1200_node_features.pkl  1_2600_edges.pkl	    2_400_edges_labels.pkl
# 0_1400_edges_labels.pkl   1_2600_node_features.pkl  2_400_edges.pkl
# 0_1400_edges.pkl	  1_2800_edges_labels.pkl   2_400_node_features.pkl
# 0_1400_node_features.pkl  1_2800_edges.pkl	    2_4200_edges_labels.pkl
# 0_1600_edges_labels.pkl   1_2800_node_features.pkl  2_4200_edges.pkl
# 0_1600_edges.pkl	  1_3000_edges_labels.pkl   2_4200_node_features.pkl
# 0_1600_node_features.pkl  1_3000_edges.pkl	    2_4400_edges_labels.pkl
# 0_1800_edges_labels.pkl   1_3000_node_features.pkl  2_4400_edges.pkl
# 0_1800_edges.pkl	  1_3200_edges_labels.pkl   2_4400_node_features.pkl
# 0_1800_node_features.pkl  1_3200_edges.pkl	    2_4600_edges_labels.pkl
# 0_2000_edges_labels.pkl   1_3200_node_features.pkl  2_4600_edges.pkl
# 0_2000_edges.pkl	  1_3400_edges_labels.pkl   2_4600_node_features.pkl
# 0_2000_node_features.pkl  1_3400_edges.pkl	    2_4800_edges_labels.pkl
# 0_200_edges_labels.pkl	  1_3400_node_features.pkl  2_4800_edges.pkl
# 0_200_edges.pkl		  1_3600_edges_labels.pkl   2_4800_node_features.pkl
# 0_200_node_features.pkl   1_3600_edges.pkl	    2_600_edges_labels.pkl
# 0_2200_edges_labels.pkl   1_3600_node_features.pkl  2_600_edges.pkl
# 0_2200_edges.pkl	  1_3800_edges_labels.pkl   2_600_node_features.pkl
# 0_2200_node_features.pkl  1_3800_edges.pkl	    2_800_edges_labels.pkl
# 0_2400_edges_labels.pkl   1_3800_node_features.pkl  2_800_edges.pkl
# 0_2400_edges.pkl	  1_4000_edges_labels.pkl   2_800_node_features.pkl
# 0_2400_node_features.pkl  1_4000_edges.pkl	    3_0_edges_labels.pkl
# 0_2600_edges_labels.pkl   1_4000_node_features.pkl  3_0_edges.pkl
# 0_2600_edges.pkl	  1_400_edges_labels.pkl    3_0_node_features.pkl
# 0_2600_node_features.pkl  1_400_edges.pkl	    3_1000_edges_labels.pkl
# 0_2800_edges_labels.pkl   1_400_node_features.pkl   3_1000_edges.pkl
# 0_2800_edges.pkl	  1_4200_edges_labels.pkl   3_1000_node_features.pkl
# 0_2800_node_features.pkl  1_4200_edges.pkl	    3_1200_edges_labels.pkl
# 0_3000_edges_labels.pkl   1_4200_node_features.pkl  3_1200_edges.pkl
# 0_3000_edges.pkl	  1_4400_edges_labels.pkl   3_1200_node_features.pkl
# 0_3000_node_features.pkl  1_4400_edges.pkl	    3_1400_edges_labels.pkl
# 0_3200_edges_labels.pkl   1_4400_node_features.pkl  3_1400_edges.pkl
# 0_3200_edges.pkl	  1_4600_edges_labels.pkl   3_1400_node_features.pkl
# 0_3200_node_features.pkl  1_4600_edges.pkl	    3_1600_edges_labels.pkl
# 0_3400_edges_labels.pkl   1_4600_node_features.pkl  3_1600_edges.pkl
# 0_3400_edges.pkl	  1_4800_edges_labels.pkl   3_1600_node_features.pkl
# 0_3400_node_features.pkl  1_4800_edges.pkl	    3_1800_edges_labels.pkl
# 0_3600_edges_labels.pkl   1_4800_node_features.pkl  3_1800_edges.pkl
# 0_3600_edges.pkl	  1_600_edges_labels.pkl    3_1800_node_features.pkl
# 0_3600_node_features.pkl  1_600_edges.pkl	    3_2000_edges_labels.pkl
# 0_3800_edges_labels.pkl   1_600_node_features.pkl   3_2000_edges.pkl
# 0_3800_edges.pkl	  1_800_edges_labels.pkl    3_2000_node_features.pkl
# 0_3800_node_features.pkl  1_800_edges.pkl	    3_200_edges_labels.pkl
# 0_4000_edges_labels.pkl   1_800_node_features.pkl   3_200_edges.pkl
# 0_4000_edges.pkl	  2_1000_edges_labels.pkl   3_200_node_features.pkl
# 0_4000_node_features.pkl  2_1000_edges.pkl	    3_2200_edges_labels.pkl
# 0_400_edges_labels.pkl	  2_1000_node_features.pkl  3_2200_edges.pkl
# 0_400_edges.pkl		  2_1200_edges_labels.pkl   3_2200_node_features.pkl
# 0_400_node_features.pkl   2_1200_edges.pkl	    3_2400_edges_labels.pkl
# 0_4200_edges_labels.pkl   2_1200_node_features.pkl  3_2400_edges.pkl
# 0_4200_edges.pkl	  2_1400_edges_labels.pkl   3_2400_node_features.pkl
# 0_4200_node_features.pkl  2_1400_edges.pkl	    3_2600_edges_labels.pkl
# 0_4400_edges_labels.pkl   2_1400_node_features.pkl  3_2600_edges.pkl
# 0_4400_edges.pkl	  2_1600_edges_labels.pkl   3_2600_node_features.pkl
# 0_4400_node_features.pkl  2_1600_edges.pkl	    3_2800_edges_labels.pkl
# 0_4600_edges_labels.pkl   2_1600_node_features.pkl  3_2800_edges.pkl
# 0_4600_edges.pkl	  2_1800_edges_labels.pkl   3_2800_node_features.pkl
# 0_4600_node_features.pkl  2_1800_edges.pkl	    3_3000_edges_labels.pkl
# 0_4800_edges_labels.pkl   2_1800_node_features.pkl  3_3000_edges.pkl
# 0_4800_edges.pkl	  2_2000_edges_labels.pkl   3_3000_node_features.pkl
# 0_4800_node_features.pkl  2_2000_edges.pkl	    3_3200_edges_labels.pkl
# 0_600_edges_labels.pkl	  2_2000_node_features.pkl  3_3200_edges.pkl
# 0_600_edges.pkl		  2_200_edges_labels.pkl    3_3200_node_features.pkl
# 0_600_node_features.pkl   2_200_edges.pkl	    3_3400_edges_labels.pkl
# 0_800_edges_labels.pkl	  2_200_node_features.pkl   3_3400_edges.pkl
# 0_800_edges.pkl		  2_2200_edges_labels.pkl   3_3400_node_features.pkl
# 0_800_node_features.pkl   2_2200_edges.pkl	    3_3600_edges_labels.pkl
# 1_1000_edges_labels.pkl   2_2200_node_features.pkl  3_3600_edges.pkl
# 1_1000_edges.pkl	  2_2400_edges_labels.pkl   3_3600_node_features.pkl
# 1_1000_node_features.pkl  2_2400_edges.pkl	    3_3800_edges_labels.pkl
# 1_1200_edges_labels.pkl   2_2400_node_features.pkl  3_3800_edges.pkl
# 1_1200_edges.pkl	  2_2600_edges_labels.pkl   3_3800_node_features.pkl
# 1_1200_node_features.pkl  2_2600_edges.pkl	    3_4000_edges_labels.pkl
# 1_1400_edges_labels.pkl   2_2600_node_features.pkl  3_4000_edges.pkl
# 1_1400_edges.pkl	  2_2800_edges_labels.pkl   3_4000_node_features.pkl
# 1_1400_node_features.pkl  2_2800_edges.pkl	    3_400_edges_labels.pkl
# 1_1600_edges_labels.pkl   2_2800_node_features.pkl  3_400_edges.pkl
# 1_1600_edges.pkl	  2_3000_edges_labels.pkl   3_400_node_features.pkl
# 1_1600_node_features.pkl  2_3000_edges.pkl	    3_4200_edges_labels.pkl
# 1_1800_edges_labels.pkl   2_3000_node_features.pkl  3_4200_edges.pkl
# 1_1800_edges.pkl	  2_3200_edges_labels.pkl   3_4200_node_features.pkl
# 1_1800_node_features.pkl  2_3200_edges.pkl	    3_4400_edges_labels.pkl
# 1_2000_edges_labels.pkl   2_3200_node_features.pkl  3_4400_edges.pkl
# 1_2000_edges.pkl	  2_3400_edges_labels.pkl   3_4400_node_features.pkl
# 1_2000_node_features.pkl  2_3400_edges.pkl	    3_600_edges_labels.pkl
# 1_200_edges_labels.pkl	  2_3400_node_features.pkl  3_600_edges.pkl
# 1_200_edges.pkl		  2_3600_edges_labels.pkl   3_600_node_features.pkl
# 1_200_node_features.pkl   2_3600_edges.pkl	    3_800_edges_labels.pkl
# 1_2200_edges_labels.pkl   2_3600_node_features.pkl  3_800_edges.pkl
# 1_2200_edges.pkl	  2_3800_edges_labels.pkl   3_800_node_features.pkl

# %%
createDir("./dataset_closeByDoublePion")
# Out:
# Creating Directory ./dataset_closeByDoublePion
